# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Converted into pandas dataframe

# %%
crime_df = pd.read_csv(r"C:\Users\PC\crimeAnalysis\Dataset\districtwise-ipc-crimes-2017-onwards.csv")
crime_df.head(5)
# Out:
#    id  year      state_name  state_code  district_name  district_code  \
# 0   0  2017  Andhra Pradesh          28  Ananthapuramu            502
# 1   1  2017  Andhra Pradesh          28       Chittoor            503
# 2   2  2017  Andhra Pradesh          28         Y.S.R.            504
# 3   3  2017  Andhra Pradesh          28  East Godavari            505
# 4   4  2017  Andhra Pradesh          28  Ananthapuramu            502
#
#   registration_circles  murder  clpbl_hmcrd_not_amt_murder  hit_and_run  ...  \
# 0            Anantapur   113.0                         4.0         50.0  ...
# 1             Chittoor    70.0                         5.0         36.0  ...
# 2             Cuddapah    88.0                        10.0         32.0  ...
# 3        East Godavari    69.0                        14.0        138.0  ...
# 4     Guntakal Railway    11.0                         0.0          0.0  ...
#
#    ofnc_religion  cheating_impersonation  ofnc_mischief  arson  \
# ...

# %% [markdown]
# Data Cleaning

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322 entries, 0 to 5321
# Columns: 124 entries, id to other_ipc_crimes
# dtypes: float64(117), int64(4), object(3)
# memory usage: 5.0+ MB

# %%
pd.set_option('display.max_rows', None)  # Shows all rows
print(crime_df.isnull().sum())
# Out:
# id                                      0
# year                                    0
# state_name                              0
# state_code                              0
# district_name                           0
# district_code                           0
# registration_circles                    0
# murder                                  0
# clpbl_hmcrd_not_amt_murder              0
# hit_and_run                             0
# acdnt_other_than_hit_and_run_           0
# deaths_negl_rel_rail_acdnt              0
# deaths_due_med_negnc                    0
# deaths_neg_civic_bodies                 0
# deaths_other_negnc                      0
# dowry_deaths                            0
# abetment_of_suicide                     0
# atmpt_cmmt_murder                       0
# atmpt_cmmt_clpb_hmcrd                   0
# atmpt_cmmt_suicide                      0
# miscarr_infant_foetic_aband             0
# vlntrly_caus_simple_hurt                0
# ...

# %%
crime_df.dtypes
# Out:
# id                                     int64
# year                                   int64
# state_name                            object
# state_code                             int64
# district_name                         object
# district_code                          int64
# registration_circles                  object
# murder                               float64
# clpbl_hmcrd_not_amt_murder           float64
# hit_and_run                          float64
# acdnt_other_than_hit_and_run_        float64
# deaths_negl_rel_rail_acdnt           float64
# deaths_due_med_negnc                 float64
# deaths_neg_civic_bodies              float64
# deaths_other_negnc                   float64
# dowry_deaths                         float64
# abetment_of_suicide                  float64
# atmpt_cmmt_murder                    float64
# atmpt_cmmt_clpb_hmcrd                float64
# atmpt_cmmt_suicide                   float64
# miscarr_infant_foetic_aband          float64
# ...

# %%
crime_df.columns
# Out:
# Index(['id', 'year', 'state_name', 'state_code', 'district_name',
#        'district_code', 'registration_circles', 'murder',
#        'clpbl_hmcrd_not_amt_murder', 'hit_and_run',
#        ...
#        'ofnc_religion', 'cheating_impersonation', 'ofnc_mischief', 'arson',
#        'criminal_trespass', 'crlty_husbnd_relatives',
#        'crcl_false_fake_news_rumours', 'criminal_intimidation',
#        'insult_modesty_women', 'other_ipc_crimes'],
#       dtype='object', length=124)
